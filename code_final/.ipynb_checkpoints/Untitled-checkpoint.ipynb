# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from results.analyse_ssim import plot_ssim
from cifar100.main_exp import load_model,load_data,compute_accuracy,calibrate_model,compute_ece,deletion_step
import configparser
import torch
from torchvision import transforms
torch.seed = 0
np.random.seed(0)

# %% [markdown]
# # Launch Experiments

# %% [markdown]
# First go to the conf file to define the parameters

# %% [markdown]
#     -Load the model
#     -Compute accuracy
#     -Compute ECE
#     -Calibrate model
#     -Deletion experiment

# %%
model = load_model()

# %%
calibration_set, test_set, data = load_data()
# Out:
# Files already downloaded and verified

# %%
compute_accuracy(model,data,3000,True)
# Out:
# =================================================>| * 99 %%
#  accuracy is : 0.478
# 0.478

# %%
wrapper,calibrator = calibrate_model(model, data,method="temperature",DEVICE="cpu")
# Out:
# =========================================>........| * 83 %%

# %%
compute_ece(wrapper, model, data, calibrator, "temperature")
# Out:
# =================================================>| * 99 %%float32
# ece non calib 0.1396320687592527
# float64
# ece calib 0.00964967040688165

# %%
transform = transforms.Compose(
    [
        # resize it to the size indicated by `image_size`
        # transforms.Resize((224, 224)),
        # convert it to a tensor
        transforms.ToTensor(),
        # normalize it to the range [−1, 1]
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
    ]
)

# %%
deletion_step( model,data, "Sensitivity", "", transform, "results",plot=True)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# KeysView(<configparser.ConfigParser object at 0x7fe1ffd0df70>)
#    forward step ...
# Class 68 predicted with a score of 0.8815973997116089
#    backward step ...
#    forward step ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-5cea93add579> in <module>
# ----> 1 deletion_step( model,data, "temperature", "Sensitivity", transform, "results",plot=True)
#
# ~/Desktop/code_final/cifar100/main_exp.py in deletion_step(model, data, method, interpretation_method, transform, WDR, plot)
#     366         # prediction = model(image.unsqueeze(0)).cpu().detach().argmax()
#     367         saliency_ref = exp(image, plot=plot, calibrator=None, device=DEVICE)
# --> 368         saliency_calib = exp(image, plot=plot, calibrator=temperature, device=DEVICE)
# ...

# %% [markdown]
# # Plots SSIM

# %%
plot_ssim("vgg16", "cifar100", "temperature")

# %%
plot_ssim("vgg16", "cifar100", "dirichlet")

# %%
plot_ssim("resnet32", "cifar100", "dirichlet")

# %%
plot_ssim("resnet32", "cifar100", "temperature")

# %%
plot_ssim("resnet50", "food101", "temperature")

# %%
plot_ssim("resnet50", "food101", "dirichlet")
