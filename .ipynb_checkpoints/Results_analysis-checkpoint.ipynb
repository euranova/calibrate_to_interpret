# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from code_final.results.analyse_ssim import plot_ssim
from code_final.results.plot_auc import plot_auc_curves
from code_final.results.total_variation import compute_TV
import configparser
import torch
from torchvision import transforms
torch.seed = 0
np.random.seed(0)

# %% [markdown]
# First
# -----
# download the results at : https://drive.google.com/drive/folders/1WLnh-xcv4lkM5bl1jcHGYtRdDMmBLXK5?usp=sharing
# and place them in the results folder

# %% [markdown]
# # Explore results
#
#    - Example with vgg16 on cifar100 using dirichlet calibration
# -------------------------

# %%
plot_ssim("vgg16", "cifar100", "dirichlet")

# %%
plot_auc_curves("vgg16", "cifar100", "dirichlet")

# %%
compute_TV("vgg16", "cifar100", "dirichlet")
# Out:
# Sensitivity mean tv after otzu binarisation after calibration : 0.02408617805936042
#  computed on 3 values
# Sensitivity mean tv after otzu binarisation before calibration : 0.022752771892639162
#  computed on 3 values
#
# Missing data for : IntegratedGradient

# %% [markdown]
#  !!! Missing data, in order to obtain results from paper, experiments need to be executed completely

# %% [markdown]
#   - Example with resnet32 on cifar100 using dirichlet calibration
# -------------------------------------------------

# %%
plot_ssim("resnet32", "cifar100", "dirichlet")

# %%
plot_auc_curves("resnet32", "cifar100", "dirichlet")

# %%
compute_TV("resnet32", "cifar100", "dirichlet")    #Same
# Out:
# Missing data for : Sensitivity

# %% [markdown]
#   - Example with resnet32 on cifar100 using temperature calibration
# -------------------------------------------------

# %%
plot_ssim("resnet32", "cifar100", "temperature")

# %%
plot_auc_curves("resnet32", "cifar100", "temperature")

# %%
compute_TV("resnet32", "cifar100", "temperature")    #Same
# Out:
# Missing data for : Sensitivity

# %% [markdown]
#   - Example with resnet32 on cifar100 using temperature calibration
# -------------------------------------------------

# %%
plot_ssim("vgg16", "cifar100", "temperature")

# %%
plot_auc_curves("vgg16", "cifar100", "temperature")

# %%
compute_TV("vgg16", "cifar100", "temperature")    #Same

# %% [markdown]
# To compute results on Food101 see Experiments notebook
# ---------------------------
