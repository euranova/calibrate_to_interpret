# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from code_final.results.analyse_ssim import plot_ssim
from code_final.cifar100.main_exp import load_model,load_data,compute_accuracy,calibrate_model,compute_ece,deletion_step
import configparser
import torch
from torchvision import transforms
torch.seed = 0
np.random.seed(0)

# %% [markdown]
# # Launch Experiments

# %% [markdown]
# First please go to the conf file to define the parameters !
# ---------------------------------

# %% [markdown]
#     -Load the model
#     -Compute accuracy
#     -Compute ECE
#     -Calibrate model
#     -Deletion experiment

# %%
model = load_model()

# %%
calibration_set, test_set, data = load_data()
# Out:
# Files already downloaded and verified

# %%
compute_accuracy(model,data,True)
# Out:
# Computing  accuracy ...
#
# =================================================>| * 99 %%
#  accuracy is : 0.51
# 0.51

# %%
wrapper,calibrator = calibrate_model(model, data,DEVICE="cpu") # output of the cell removed for anonymization
# Out:
# Calibrating model ...
#
# =========================================>........| * 83 %%

# %%
compute_ece(wrapper, model, data, calibrator)
# Out:
# Computing expected calibration error ...
#
# =================================================>| * 99 %%float32
# ece non calib 0.19508686500943567
# float64
# ece calib 0.03453305394016701

# %%
transform = transforms.Compose(
    [
        # resize it to the size indicated by `image_size`
        # transforms.Resize((224, 224)),
        # convert it to a tensor
        transforms.ToTensor(),
        # normalize it to the range [−1, 1]
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
    ]
)

# %%
deletion_step( model,data, "Sensitivity", "Sensitivity", transform, "results",plot=True) # manually interrupted
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Deletion experiments ...
#
# <bound method Mapping.keys of <configparser.ConfigParser object at 0x7ffb876cf4c0>>
# TemperatureScaling(_default_independent_probabilities=False, _num_combination=0,
#                    _weights=array([0.49136811]), num_classes=100,
#                    temperature_only=True)
# temperature
#    forward step ...
# Class 24 predicted with a score of 0.5543515682220459
#    backward step ...
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#    forward step ...
# Class 24 predicted with a score of 0.25591978430747986
#    backward step ...
# 100
# 100
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0
#    forward step ...
# Class 80 predicted with a score of 0.4646168649196625
#    backward step ...
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#    forward step ...
# Class 80 predicted with a score of 0.168417826294899
#    backward step ...
# 100
# 100
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1
#    forward step ...
# Class 55 predicted with a score of 0.9982050657272339
#    backward step ...
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#    forward step ...
# Class 55 predicted with a score of 0.8352184295654297
#    backward step ...
# 100
# 100
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2
#    forward step ...
# Class 51 predicted with a score of 0.9999459981918335
#    backward step ...
#    forward step ...
# Class 51 predicted with a score of 0.9528332948684692
#    backward step ...
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100
# 100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-e6999b8e16a7> in <module>
# ----> 1 deletion_step( model,data, "Sensitivity", "Sensitivity", transform, "results",plot=True)
#
# ~/Desktop/supplementary_materials/code_final/cifar100/main_exp.py in deletion_step(model, data, method, interpretation_method, transform, WDR, plot)
#     414         )
#     415
# --> 416         auc_random = deletion_random(
#     417             model,
#     418             image,
#
# ~/Desktop/supplementary_materials/code_final/cifar100/utils/utils.py in wrapper_func(*args, **kwargs)
#      40                 except Exception:
#      41                     args[i] = tuple([args[i][j].to(dev) for j in range(len(args[i]))])
# ---> 42         saliency = func(*args, **kwargs)
#      43         return saliency
#      44
#
# ~/Desktop/supplementary_materials/code_final/cifar100/metrics/mesures_mean.py in deletion_random(model, image, saliency_map, plot, auc_value, background, insertion, gpu, end, name, calibrated, file, seed)
#     446                 if gpu:
#     447                     masked_image.to(DEVICE)
# --> 448                 score = do_prediction(model, masked_image, calibrated)
#     449                 # print("at {} score : {}".format(i, score[0, true_prediction]))
#     450                 scores_list[0, i + 1] = score.detach()[0, true_prediction]
#
# ~/Desktop/supplementary_materials/code_final/cifar100/metrics/mesures_mean.py in do_prediction(model, image, calibrated)
#     210     # Apply model to input image
#     211     if type(calibrated) is str:
# --> 212         scores = nn.Softmax(dim=-1)(model(image.unsqueeze(0)))
#     213     else:
#     214         if config["SCALER"]["method"] == "dirichlet":
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.cache/torch/hub/chenyaofo_pytorch-cifar-models_master/pytorch_cifar_models/vgg.py in forward(self, x)
#      81
#      82     def forward(self, x: torch.Tensor) -> torch.Tensor:
# ---> 83         x = self.features(x)
#      84         x = torch.flatten(x, 1)
#      85         x = self.classifier(x)
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     441
#     442     def forward(self, input: Tensor) -> Tensor:
# --> 443         return self._conv_forward(input, self.weight, self.bias)
#     444
#     445 class Conv3d(_ConvNd):
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     437                             weight, bias, self.stride,
#     438                             _pair(0), self.dilation, self.groups)
# --> 439         return F.conv2d(input, weight, bias, self.stride,
#     440                         self.padding, self.dilation, self.groups)
#     441
#
# KeyboardInterrupt:

# %% [markdown]
# In order to save images in the right folder launch the file as a module :
#  ------------------------------
#  ```
#      python -m code_final.cifar100.main_exp
#  ```
